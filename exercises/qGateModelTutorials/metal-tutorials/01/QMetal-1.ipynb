# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import Qiskit Metal
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %metal_heading Welcome to Qiskit Metal!
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Welcome to Qiskit Metal! <h1>

# %%
# My First Quantum Design (QDesign)

design = designs.DesignPlanar()

# %%
design.overwrite_enabled = True

# %%
# %metal_heading Hello Quantum Hardware World!
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Hello Quantum Hardware World! <h1>

# %%
design.chips.main
# Out:
# {'material': 'silicon',
#  'layer_start': '0',
#  'layer_end': '2048',
#  'size': {'center_x': '0.0mm',
#   'center_y': '0.0mm',
#   'center_z': '0.0mm',
#   'size_x': '9mm',
#   'size_y': '6mm',
#   'size_z': '-750um',
#   'sample_holder_top': '890um',
#   'sample_holder_bottom': '1650um'}}

# %%
design.chips.main.size.size_x = '11mm'
design.chips.main.size.size_y = '9mm'

# %%
gui = MetalGUI(design)
# Out:
# 10:37PM 23s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsWindow::setMouseGrabEnabled: Not setting mouse grab for invisible window QWidgetWindow/'menuRenderWindow'
#
# 10:37PM 26s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsWindow::setMouseGrabEnabled: Not setting mouse grab for invisible window QWidgetWindow/'menuAnalysisWindow'
#
# 10:37PM 49s ERROR [do_debug]: Traceback (most recent call last):
#   File "c:\users\ovidi\projects\ibmqx\github-qiskit-metal\qiskit-metal\qiskit_metal\_gui\utility\_handle_qt_messages.py", line 133, in wrapper
#     func(*args)
#   File "c:\users\ovidi\projects\ibmqx\github-qiskit-metal\qiskit-metal\qiskit_metal\_gui\main_window_base.py", line 259, in load_stylesheet_dark
#     self.handler.load_stylesheet('qdarkstyle')
#   File "c:\users\ovidi\projects\ibmqx\github-qiskit-metal\qiskit-metal\qiskit_metal\_gui\main_window_base.py", line 533, in load_stylesheet
#     self.main_window.setStyleSheet(qdarkstyle.load_stylesheet())
# UnboundLocalError: local variable 'qdarkstyle' referenced before assignment
#
#
# ERROR in call by Metal GUI (see traceback above)
#
#  module   :  qiskit_metal._gui.main_window_base
#  function :  QMainWindowExtensionBase.load_stylesheet_dark
#  err msg  :  UnboundLocalError("local variable 'qdarkstyle' referenced before assignment")
#  args; kws:  (<qiskit_metal._gui.main_window.QMainWindowExtension object at 0x000002150EA87188>,); {}

# %%
# My First Quantum Component (QComponent)

# Select a QComponent to create( The QComponent is a python class named 'TransmonPocket')
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket

q1 = TransmonPocket(design, 'Q1', options=dict(connection_pads=dict(a=dict()))) # Create a new TransmonPocket named 'Q1'
gui.rebuild() # rebuid the design and plot

gui.edit_component('Q1') #set Q1 as the editable component
gui.autoscale() # resize GUI to see QComponent

# %%
q1 # print Q1 information
# Out:
# name:    Q1
# class:   TransmonPocket
# options:
#   'pos_x'             : '0um',
#   'pos_y'             : '0um',
#   'connection_pads'   : {
#        'a'                 : {
#             'pad_gap'           : '15um',
#             'pad_width'         : '125um',
#             'pad_height'        : '30um',
#             'pad_cpw_shift'     : '5um',
#             'pad_cpw_extent'    : '25um',
#             'cpw_width'         : 'cpw_width',
#             'cpw_gap'           : 'cpw_gap',
#             'cpw_extend'        : '100um',
#             'pocket_extent'     : '5um',
#             'pocket_rise'       : '65um',
#             'loc_W'             : '+1',
#             'loc_H'             : '+1',
#                              },
#                         },
#   'pad_gap'           : '30um',
#   'inductor_width'    : '20um',
#   'pad_width'         : '455um',
#   'pad_height'        : '90um',
#   'pocket_width'      : '650um',
#   'pocket_height'     : '650um',
#   'orientation'       : '0',
#   'hfss_inductance'   : '10nH',
#   'hfss_capacitance'  : 0,
#   'hfss_resistance'   : 0,
#   'hfss_mesh_kw_jj'   : 7e-06,
#   'q3d_inductance'    : '10nH',
#   'q3d_capacitance'   : 0,
#   'q3d_resistance'    : 0,
#   'q3d_mesh_kw_jj'    : 7e-06,
#   'gds_cell_name'     : 'my_other_junction',
# module:  qiskit_metal.qlibrary.qubits.transmon_pocket
# id:      1

# %%
# %metal_print How do I edit options? API or GUI
# Out:
#     <div style="
#         padding-top:10px;
#         padding-bottom:10px;
#         font-weight: bold;
#         font-size: large;
#         text-align: center;
#         color: white;
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #f64f59, #c471ed, #12c2e9);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(to right, #f64f59, #c471ed, #12c2e9); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#     ">
#         How do I edit options? API or GUI
#     </div>

# %%
# Change options
q1.options.pos_x = '0.5 mm'
q1.options.pos_y = '0.25 mm'
q1.options.pad_height = '225 um'
q1.options.pad_width  = '250 um'
q1.options.pad_gap    = '50 um'

# %%
gui.rebuild() # Update the component geometry

# Get a list of all the qcomponents in QDesign and then zoom on them
all_component_names = design.components.keys()

gui.zoom_on_components(all_component_names)
# Out:
# 10:53PM 54s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsWindow::setMouseGrabEnabled: Not setting mouse grab for invisible window QWidgetWindow/'menuAnalysisWindow'
#
# 10:53PM 58s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsWindow::setMouseGrabEnabled: Not setting mouse grab for invisible window QWidgetWindow/'menuRenderWindow'
#
# 10:54PM 02s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsWindow::setMouseGrabEnabled: Not setting mouse grab for invisible window QWidgetWindow/'menuRenderWindow'
#
# 10:54PM 02s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsWindow::setMouseGrabEnabled: Not setting mouse grab for invisible window QWidgetWindow/'menuAnalysisWindow'
# 10:54PM 56s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.metal' not found in 'All Files (*)'.
#
# 10:54PM 56s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.metal' not found in 'All Files (*)'.
#
# 10:55PM 11s WARNING [save_design]: Saving is a beta feature.
# 10:55PM 11s INFO [save_design]: Saving design to C:/Users/ovidi/Projects/IBMQX/github-qiskit-metal/tutorial-metal/my_design.metal
# 10:55PM 11s WARNING [find_id]: In Components.find_id(), the name=__getstate__ is not used in design._components
# 10:55PM 11s ERROR [log_error_easy]:
#
# Traceback (most recent call last):
#
#   File "c:\users\ovidi\projects\ibmqx\github-qiskit-metal\qiskit-metal\qiskit_metal\toolbox_metal\import_export.py", line 52, in save_metal
#     pickle.dump(self, open(filename, "wb"))
#
# TypeError: 'NoneType' object is not callable
#
# ERROR WHILE SAVING: 'NoneType' object is not callable
# 10:55PM 11s ERROR [save_design]: Saving failed.
# 10:55PM 23s WARNING [save_design]: Saving is a beta feature.
# 10:55PM 23s INFO [save_design]: Saving design to C:/Users/ovidi/Projects/IBMQX/github-qiskit-metal/tutorial-metal/my_design.metal
# 10:55PM 23s WARNING [find_id]: In Components.find_id(), the name=__getstate__ is not used in design._components
# 10:55PM 23s ERROR [log_error_easy]:
#
# Traceback (most recent call last):
#
#   File "c:\users\ovidi\projects\ibmqx\github-qiskit-metal\qiskit-metal\qiskit_metal\toolbox_metal\import_export.py", line 52, in save_metal
#     pickle.dump(self, open(filename, "wb"))
#
# TypeError: 'NoneType' object is not callable
#
# ERROR WHILE SAVING: 'NoneType' object is not callable
# 10:55PM 23s ERROR [save_design]: Saving failed.

# %%
# Closing the Qiskit Metal GUI
gui.main_window.close()
