# %%
from qiskit import *

# %%
nqubits = 3
circuit2 = QuantumCircuit(nqubits, nqubits)
circuit2.x(1)
circuit2.h(0)
circuit2.cx(0,1)
circuit2.cx(1,2)
circuit2.measure([0,1,2], [0,1,2])
circuit2.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')

from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(

    execute(circuit2, backend=simulator, shots = 1024).result().get_counts(circuit2)
    
)

# %%
# running on a real QC device
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
# device = provider.get_backend('ibmq_5_yorktown')
# Out:
# ibmqfactory.load_account:WARNING:2021-03-06 14:41:08,198: Credentials are already in use. The existing account in the session will be replaced.

# %%
from qiskit.ignis.mitigation.measurement import (complete_meas_cal, CompleteMeasFitter)

# %%
cal_circuits, state_labeles = complete_meas_cal(qr = circuit.qregs[0], circlabel = 'measerrormitigationcal')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-78055acb5096> in <module>
# ----> 1 cal_circuits, state_labeles = complete_meas_cal(qr = circuit.qregs[0], circlabel = 'measerrormitigationcal')
#
# AttributeError: module 'qiskit.circuit' has no attribute 'qregs'
